# %% [markdown]
# # Chat Completions API
#
# Chat Completions API는 `messages` 배열을 입력받아 다음 대화 응답을 만드는 인터페이스이다. 각 요청에는 역할과 대화 순서를 함께 보내므로, 애플리케이션이 이전 대화를 직접 누적해야 한다.
#
# 이 노트북은 역할 기반 메시지, 대화 누적, 스트리밍, 사용량과 토큰 비용 추정을 다룬다. 새 텍스트 앱에서는 Responses API가 기본 권장 경로이지만, 기존 `messages` 기반 서비스와 API 구조를 이해하려면 Chat Completions도 알아야 한다.

# %% [markdown]
# ## 메시지와 주요 요청 값
#
# Chat Completions API는 대화 이력인 `messages`를 입력으로 받는다. 결과는 하나의 assistant 메시지로 반환한다. 서버가 호출 사이의 대화를 자동으로 기억하지 않으므로, 애플리케이션이 이전 메시지를 순서대로 다시 보내야 한다.
#
# 메시지 역할은 다음과 같다.
#
# - `system`: 모델의 역할, 태도, 응답 제약을 지정한다.
# - `user`: 사용자의 질문이나 요청을 담는다.
# - `assistant`: 이전 모델 응답을 담아 다음 요청의 문맥으로 사용한다.
#
# 주요 요청 값은 다음과 같다.
#
# - `model`: 호출할 모델 ID이다. 저비용 예시는 `gpt-5.6-luna`를 사용한다.
# - `messages`: 역할과 내용으로 구성한 대화 이력 배열이다.
# - `stream`: `True`이면 완성 문장 대신 부분 응답 청크를 순서대로 받는다.
# - 생성 제어 값은 모델별 지원 범위를 확인한다. GPT-5.6 계열은 Responses API의 `reasoning.effort`를 먼저 비교한다.
#
# 공식 문서는 다음과 같다.
#
# - [Chat Completions 생성 API](https://developers.openai.com/api/reference/resources/chat/subresources/completions/methods/create)
# - [텍스트 생성 가이드](https://developers.openai.com/api/docs/guides/text)
# - [GPT-5.6 모델 지침](https://developers.openai.com/api/docs/guides/latest-model)

# %% [markdown]
# ### API 클라이언트 준비
#
# 이미 학습한 `.env` 설정을 불러와 `OPENAI_API_KEY`를 현재 커널에 등록한다. 키 값은 출력하지 않으며, `OpenAI()`가 환경 변수에서 키를 읽어 이후 요청에 사용한다.

# %%
from dotenv import find_dotenv, load_dotenv
from openai import OpenAI

dotenv_path = find_dotenv(usecwd=True)
if not dotenv_path:
    raise FileNotFoundError("08_llm 프로젝트 최상위에 .env 파일을 만든 뒤 다시 실행한다.")
load_dotenv(dotenv_path, override=False)

client = OpenAI()

print("OpenAI 클라이언트 준비 완료")
# Out:
# OpenAI 클라이언트 준비 완료

# %% [markdown]
# ## 역할 기반 메시지와 단일 응답
#
# 첫 요청은 `system`, `user`, `assistant`, `user` 순서의 대화 이력을 모델에 보낸다.
#
# - `response.choices[0].message.content`는 이번 호출의 완성 응답이다.
# - 반복 대화에서는 이 값을 다음 `messages`에 assistant 역할로 추가한다.

# %% [markdown]
# ### 이름을 문맥에서 다시 찾기
#
# 입력 `messages`에는 사용자가 이름을 말한 턴과 이전 assistant 응답이 함께 들어간다. 모델은 그 이력을 변환해 이번 질문의 응답을 `response`에 만들고, 출력 문자열은 다음 턴의 문맥으로 저장할 수 있다.

# %%
MODEL_NAME = "gpt-5.6-luna"

response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        # 공통 지침
        {"role":"system", "content":"너는 친절한 챗봇이다."},

        # 이전 대화 내용
        {"role":"user", "content":"안녕, 내 이름은 홍길동이야."},
        {"role":"assistant", "content":""},

        # 새로운 대화 내용
        {"role":"user", "content":"잘 지냈어? 내 이름을 기억하니?"},
    ]   # 모델이 이전 대화를 기억할 수 있게 하는 '리스트' <-- 이전 값도 같이 전달하여 "너와 내가 이런 대화를 나누었다"를 표현.
)

# 결과값 출력
assistant_message = response.choices[0].message.content
print(assistant_message)

def used_tokens(response):
    print("prompt_tokens:", response.usage.prompt_tokens)
    print("completion_tokens:", response.usage.completion_tokens)
    print("total_tokens:", response.usage.total_tokens)

used_tokens(response)
# Out:
# 네, 잘 지냈어요! 이름은 **홍길동**으로 기억하고 있어요. 만나서 반가워요, 홍길동님 😊
# prompt_tokens: 55
# completion_tokens: 35
# total_tokens: 90

# %% [markdown]
# ### 긴 대화 이력으로 요약 요청 만들기
#
# 이 예시는 Transformer 설명, 쉬운 비유 요청, 마지막 요약 요청을 하나의 `messages` 배열에 누적한다. 마지막 응답은 앞선 대화 전체를 입력으로 사용하므로, 단일 프롬프트보다 긴 문맥을 반영하는 결과를 확인할 수 있다.

# %%
# chat completion을 이용해서 응답을 받은 후 응답 결과, 토큰 사용량 출력

MODEL_NAME = "gpt-5.6-luna"

response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        # 공통 지침
        {"role": "system", "content": "너는 LLM 전문가이다."},
    {"role": "user", "content": "안녕, 나는 LLM을 배우는 차은우야."},
    {"role": "assistant", "content": "안녕, 차은우. LLM에서 궁금한 점을 말해 줘."},
    {"role": "user", "content": "Transformer 모델을 공부하고 싶어."},
    {"role": "assistant", "content": "Transformer는 인코더와 디코더, 자기 주의, 위치 정보로 문맥을 처리하는 구조이다. 번역과 요약에 사용할 수 있다."},
    {"role": "user", "content": "어려워. 어텐션을 초등학생도 이해할 수 있게 설명해 줘."},
    {"role": "assistant", "content": "어텐션은 문장에서 중요한 단어에 더 집중하도록 가중치를 주는 방법이다. 예를 들어 강아지 이야기에서는 강아지와 관련된 단어를 더 참고한다."},
    {"role": "user", "content": "이해가 되는 것 같아. Transformer 내용을 Markdown 문서로 요약해 줘."},
    ]   # 모델이 이전 대화를 기억할 수 있게 하는 '리스트' <-- 이전 값도 같이 전달하여 "너와 내가 이런 대화를 나누었다"를 표현.
)

# 결과값 출력
assistant_message = response.choices[0].message.content
print(assistant_message)

def used_tokens(response):
    print("prompt_tokens:", response.usage.prompt_tokens)
    print("completion_tokens:", response.usage.completion_tokens)
    print("total_tokens:", response.usage.total_tokens)

used_tokens(response)
# Out:
# # Transformer 모델 요약
#
# ## 1. Transformer란?
#
# **Transformer**는 문장 속 단어들의 관계를 파악하여 텍스트를 처리하는 딥러닝 모델이다.
#
# 2017년 논문 **「Attention Is All You Need」**에서 소개되었으며, 현재의 번역·요약·질의응답·챗봇·생성형 AI의 핵심 구조로 사용된다.
#
# ---
#
# ## 2. Transformer의 핵심 아이디어
#
# Transformer는 문장을 읽을 때 모든 단어를 똑같이 보는 것이 아니라, 현재 단어와 관련이 깊은 단어에 더 집중한다.
#
# 예를 들어 다음 문장이 있다고 하자.
#
# > 철수는 도서관에서 책을 읽었다. 그는 매우 조용했다.
#
# 여기서 **“그는”**이 누구를 가리키는지 이해하려면 **“철수”**를 중요하게 참고해야 한다.
# Transformer는 이런 단어 간의 관계를 **어텐션(Attention)**으로 계산한다.
#
# ---
#
# ## 3. 어텐션(Attention)
#
# ### 3.1 어텐션이란?
#
# 어텐션은 문장 안에서 **어떤 단어를 얼마나 중요하게 참고할지 계산하는 방법**이다.
#
# 쉽게 말하면 다음과 같다.
#
# > “이 단어를 이해하려면 문장 속 어떤 단어를 더 살펴봐야 할까?”
#
# 각 단어에 중요도 점수를 부여하고, 중요한 단어의 정보를 더 많이 반영한다.
#
# ### 3.2 예시
#
# 문장:
#
# > 고양이가 소파 위에서 잠을 잔다.
#
# “잠을 잔다”를 이해할 때 다음 단어들을 참고할 수 있다.
#
# - 고양이: 누가 잠을 자는가?
# - 소파: 어디에서 잠을 자는가?
# - 위에서: 위치 정보
#
# Transformer는 단어들 사이의 관련성을 계산하여 문장의 의미를 파악한다.
#
# ---
#
# ## 4. 셀프 어텐션(Self-Attention)
#
# **셀프 어텐션**은 한 문장 안의 단어들이 서로를 참고하는 방식이다.
#
# 예를 들어 문장 속 각 단어가 다음과 같은 질문을 한다.
#
# - 나는 어떤 단어와 관련이 있는가?
# - 어떤 단어의 정보가 나를 이해하는 데 중요한가?
# - 다른 단어와 어떤 관계를 맺고 있는가?
#
# 이를 통해 Transformer는 단어 하나만 보는 것이 아니라 **문장 전체의 문맥**을 고려한다.
#
# ---
#
# ## 5. Query, Key, Value
#
# 어텐션은 보통 다음 세 가지 정보로 설명할 수 있다.
#
# | 요소 | 의미 |
# |---|---|
# | Query | 내가 찾고 있는 정보 |
# | Key | 각 단어가 가진 특징 또는 검색용 정보 |
# | Value | 실제로 전달할 정보 |
#
# 도서관에 비유하면 다음과 같다.
#
# - **Query**: 찾고 싶은 책의 주제
# - **Key**: 책의 제목이나 분류 정보
# - **Value**: 책 안의 실제 내용
#
# Query와 Key가 얼마나 잘 맞는지 계산한 뒤, 관련성이 높은 Value를 더 많이 가져온다.
#
# ---
#
# ## 6. Multi-Head Attention
#
# Transformer는 어텐션을 한 번만 계산하지 않고 여러 개의 관점에서 동시에 계산한다. 이를 **멀티 헤드 어텐션(Multi-Head Attention)**이라고 한다.
#
# 각 헤드는 서로 다른 관계를 볼 수 있다.
#
# - 어떤 헤드: 주어와 동사의 관계 파악
# - 어떤 헤드: 대명사가 가리키는 대상 파악
# - 어떤 헤드: 가까운 단어들의 관계 파악
# - 어떤 헤드: 문장 전체의 의미 파악
#
# 여러 관점을 합치면 문장을 더 풍부하게 이해할 수 있다.
#
# ---
#
# ## 7. Transformer의 기본 구조
#
# Transformer는 크게 **인코더(Encoder)**와 **디코더(Decoder)**로 구성된다.
#
# ```text
# 입력 문장
#    ↓
# 인코더
#    ↓
# 문맥이 반영된 표현
#    ↓
# 디코더
#    ↓
# 출력 문장
# ```
#
# ### 7.1 인코더
#
# 인코더는 입력 문장을 읽고 문맥을 이해한다.
#
# 예를 들어 영어 문장을 입력하면 각 단어의 의미와 단어 간 관계를 표현으로 변환한다.
#
# ### 7.2 디코더
#
# 디코더는 인코더가 만든 정보를 참고하여 출력 문장을 한 단어씩 생성한다.
#
# 번역을 예로 들면 다음과 같다.
#
# ```text
# 영어 문장 → 인코더 → 문장 이해
#                          ↓
#                     디코더 → 한국어 문장 생성
# ```
#
# ---
#
# ## 8. Transformer의 주요 구성 요소
#
# ### 8.1 임베딩(Embedding)
#
# 컴퓨터는 단어 자체를 이해하지 못하므로 단어를 숫자 벡터로 바꾼다.
# 이 과정을 **임베딩**이라고 한다.
#
# ```text
# "강아지" → [0.21, -0.45, 0.73, ...]
# ```
#
# 비슷한 의미의 단어는 벡터 공간에서 비슷한 위치에 나타날 수 있다.
#
# ---
#
# ### 8.2 위치 인코딩(Positional Encoding)
#
# 어텐션만 사용하면 단어의 순서를 알기 어렵다.
#
# 예를 들어 다음 두 문장은 단어가 같지만 의미가 다르다.
#
# ```text
# 고양이가 강아지를 쫓는다.
# 강아지가 고양이를 쫓는다.
# ```
#
# 그래서 Transformer는 각 단어의 위치 정보를 추가한다. 이를 **위치 인코딩**이라고 한다.
#
# ---
#
# ### 8.3 피드 포워드 신경망(Feed-Forward Network)
#
# 어텐션으로 단어 간 관계를 계산한 뒤, 각 단어의 표현을 작은 신경망에 통과시켜 더 복잡하게 변환한다.
#
# ---
#
# ### 8.4 잔차 연결(Residual Connection)
#
# 각 층의 입력 정보를 출력에 다시 더해 주는 구조이다.
#
# ```text
# 출력 = 변환된 정보 + 원래 정보
# ```
#
# 깊은 신경망에서도 정보가 잘 전달되도록 도와준다.
#
# ---
#
# ### 8.5 정규화(Layer Normalization)
#
# 신경망의 값이 지나치게 커지거나 작아지지 않도록 조정한다.
# 학습을 안정적으로 만드는 역할을 한다.
#
# ---
#
# ## 9. Transformer 블록의 흐름
#
# Transformer의 한 층은 대략 다음 순서로 작동한다.
#
# ```text
# 입력
#  ↓
# 셀프 어텐션
#  ↓
# 잔차 연결 및 정규화
#  ↓
# 피드 포워드 신경망
#  ↓
# 잔차 연결 및 정규화
#  ↓
# 출력
# ```
#
# 이러한 층을 여러 개 쌓아 더 복잡한 문맥을 학습한다.
#
# ---
#
# ## 10. GPT와 BERT의 관계
#
# Transformer 구조는 사용하는 방식에 따라 여러 모델로 발전했다.
#
# | 모델 | 구조 | 주요 용도 |
# |---|---|---|
# | BERT | 인코더 중심 | 문장 이해, 분류, 검색 |
# | GPT | 디코더 중심 | 텍스트 생성, 대화 |
# | T5 | 인코더-디코더 | 번역, 요약, 질의응답 |
#
# ### GPT
#
# 앞에 나온 단어들을 참고하여 다음 단어를 예측한다.
#
# ```text
# 오늘 날씨가 매우 ...
# → 좋다 / 춥다 / 덥다
# ```
#
# ### BERT
#
# 문장의 양쪽 문맥을 모두 참고하여 단어의 의미를 이해한다.
#
# ```text
# 나는 ___에 갔다.
# ```
#
# 빈칸에 들어갈 단어를 문장 전체의 문맥으로 추론할 수 있다.
#
# ---
#
# ## 11. Transformer의 장점
#
# - 문장 전체의 문맥을 잘 파악한다.
# - 문장을 순서대로만 읽지 않아 병렬 처리가 가능하다.
# - 긴 거리의 단어 관계도 학습할 수 있다.
# - 대규모 데이터와 컴퓨팅 자원을 활용하기 좋다.
# - 번역, 요약, 생성, 검색 등 다양한 작업에 적용할 수 있다.
#
# ---
#
# ## 12. Transformer의 한계
#
# - 문장이 길어질수록 어텐션 계산량이 크게 증가한다.
# - 학습에 많은 데이터와 GPU 자원이 필요하다.
# - 학습 데이터에 포함된 편견을 배울 수 있다.
# - 사실이 아닌 내용을 그럴듯하게 생성할 수 있다.
# - 문장의 의미를 사람처럼 실제로 이해한다고 보기는 어렵다.
#
# ---
#
# ## 13. 전체 작동 과정
#
# Transformer가 문장을 처리하는 기본 과정은 다음과 같다.
#
# ```text
# 1. 문장을 여러 토큰으로 나눈다.
# 2. 토큰을 숫자 벡터로 변환한다.
# 3. 위치 정보를 추가한다.
# 4. 셀프 어텐션으로 단어 간 관계를 계산한다.
# 5. 여러 신경망 층에서 정보를 변환한다.
# 6. 학습 목적에 따라 다음 단어 또는 정답을 예측한다.
# 7. 예측 결과와 정답의 차이를 이용해 모델을 학습한다.
# ```
#
# ---
#
# ## 14. 핵심 한 문장
#
# > **Transformer는 어텐션을 이용해 문장 속 단어들이 서로 어떤 관계를 맺고 있는지 파악하는 신경망 구조이다.**
#
# ---
#
# ## 15. 핵심 용어 정리
#
# | 용어 | 설명 |
# |---|---|
# | Transformer | 어텐션을 중심으로 만든 신경망 구조 |
# | Attention | 중요한 정보에 더 집중하는 방법 |
# | Self-Attention | 문장 안의 단어들이 서로를 참고하는 방법 |
# | Multi-Head Attention | 여러 관점에서 어텐션을 계산하는 방법 |
# | Encoder | 입력 문장을 이해하는 부분 |
# | Decoder | 출력 문장을 생성하는 부분 |
# | Embedding | 단어를 숫자 벡터로 바꾸는 과정 |
# | Positional Encoding | 단어의 위치 정보를 표현하는 방법 |
# | Token | 문장을 나눈 작은 단위 |
# | GPT | 디코더 기반 텍스트 생성 모델 |
# | BERT | 인코더 기반 문장 이해 모델 |
#
# ---
#
# ### 한 줄 비유
#
# Transformer는 문장을 읽을 때 **모든 단어를 똑같이 보지 않고, 현재 이해에 중요한 단어들을 골라 집중해서 읽는 똑똑한 독자**와 같다.
# prompt_tokens: 207
# completion_tokens: 2321
# total_tokens: 2528

# %% [markdown]
# ## 대화 이력 누적
#
# 반복 대화에서는 사용자 입력을 `user` 메시지로 넣고, 완성된 모델 응답을 `assistant` 메시지로 다시 넣는다. 두 값을 모두 누적해야 다음 질문에서 모델이 직전 질문과 자신의 답변을 함께 읽는다.

# %% [markdown]
# ### 완성 응답을 messages에 저장하는 챗봇
#
# `input()`이 만든 사용자 문자열을 `messages`에 추가한 뒤 Chat Completions를 호출한다. 반환된 `assistant_message`를 같은 배열에 추가하므로, 다음 반복의 입력이 이전 대화 전체가 된다.

# %%
messages = [{"role":"system", "content":"너는 까칠한 챗봇이야."}]

while True: # 무한루프
    user_input = input("사용자 입력 (종료는 exit)")

    if user_input.lower().strip() == 'exit':
        print("종료합니다")
        break

    # 사용자 입력 내용을 messages에 누적
    messages.append({"role":"user", "content":user_input})

    # openai chat completions api로 요청
    response = client.chat.completions.create(
        model = MODEL_NAME,
        messages = messages
    )

    # api 응답(==llm 응답)을 messages에 누적
    assistant_message = response.choices[0].message.content
    messages.append({"role":"assistant", "content":assistant_message})
    print("Assistant:", assistant_message)

used_tokens(response)
# Out:
# Assistant: 그래, 홍길동. 이름은 알겠어. 무슨 용건이지?
# Assistant: 대충 “아무거나” 말고 골라봐, 홍길동.
#
# - **든든하게:** 제육볶음 + 밥
# - **깔끔하게:** 냉면이나 쌀국수
# - **빠르게:** 김밥 + 라면
# - **비 오는 날:** 칼국수
# - **다이어트 중이면:** 닭가슴살 샐러드 말고, 포케라도 먹어
#
# 오늘은 **제육볶음** 추천. 실패 확률이 낮거든.
# Assistant: 그럼 **쌀국수** 먹어. 주문부터 식사까지 빠르고, 국물도 깔끔해.
# 더 간단하게는 **참치김밥 + 우동**도 괜찮고.
# 종료합니다
# prompt_tokens: 201
# completion_tokens: 90
# total_tokens: 291

# %% [markdown]
# ## 스트리밍 응답과 청크 누적
#
# 스트리밍은 한 번에 완성된 메시지를 받지 않고 `delta.content` 조각을 순서대로 받는다. 화면 출력만 하면 다음 턴에 넣을 완성 응답이 없으므로, 각 조각을 리스트에 모아 `"".join()`으로 합쳐야 한다.

# %% [markdown]
# ### 단일 요청의 스트리밍 청크 출력
#
# `stream=True`는 응답을 청크 반복자로 바꾼다. 각 청크의 텍스트를 즉시 출력해 생성 과정을 보며, 같은 텍스트를 누적하면 파일 저장이나 대화 이력 추가에도 사용할 수 있다.

# %%
stream = client.chat.completions.create(
    model="gpt-5.6-luna",
    messages=[{"role": "user", "content": "스트리밍을 설명하는 30줄 짜리 응답을 만들어 줘."}],
    stream=True,
)   # chunk 단위로 분리 및 출력. (not just word)
    # 원본을 쪼개서 딱딱딱 그만큼씩만 이어서 봄.

# 스트리밍은 비어 있지 않은 새 텍스트만 누적해 전체 응답을 만든다.
response_parts = []
for chunk in stream:
    content = chunk.choices[0].delta.content
    if content:
        response_parts.append(content)
        print(content, end="", flush=True)

assistant_message = "".join(response_parts)
print()
# Out:
# 1. 스트리밍은 인터넷을 통해 콘텐츠를 실시간 또는 연속적으로 전송하는 기술입니다.
# 2. 사용자는 파일 전체를 다운로드하지 않아도 콘텐츠를 바로 재생할 수 있습니다.
# 3. 대표적인 스트리밍 콘텐츠로는 동영상, 음악, 게임 방송이 있습니다.
# 4. 넷플릭스와 유튜브는 동영상 스트리밍 서비스의 예입니다.
# 5. 스포티파이와 멜론은 음악 스트리밍 서비스에 해당합니다.
# 6. 트위치와 아프리카TV는 실시간 방송 스트리밍을 제공합니다.
# 7. 스트리밍은 콘텐츠를 작은 데이터 조각으로 나누어 전송합니다.
# 8. 이용자의 기기는 데이터를 받는 즉시 재생을 시작합니다.
# 9. 재생과 동시에 다음 데이터 조각이 계속 다운로드됩니다.
# 10. 이때 임시로 저장되는 공간을 버퍼라고 합니다.
# 11. 버퍼는 네트워크가 잠시 느려져도 재생을 이어 가도록 도와줍니다.
# 12. 네트워크 속도가 너무 느리면 버퍼링이 발생할 수 있습니다.
# 13. 버퍼링은 데이터가 재생 속도를 따라오지 못할 때 나타납니다.
# 14. 스트리밍 품질은 인터넷 속도와 연결 안정성의 영향을 받습니다.
# 15. 영상 해상도가 높을수록 더 많은 데이터가 필요합니다.
# 16. 일반적으로 4K 영상은 HD 영상보다 훨씬 큰 대역폭을 사용합니다.
# 17. 스트리밍 서비스는 사용자의 환경에 맞춰 화질을 자동 조절하기도 합니다.
# 18. 이러한 기능을 적응형 비트레이트 스트리밍이라고 합니다.
# 19. 비트레이트는 일정 시간 동안 전송되는 데이터의 양을 뜻합니다.
# 20. 비트레이트가 높으면 보통 화질과 음질이 좋아집니다.
# 21. 대신 데이터 사용량과 네트워크 요구량도 증가합니다.
# 22. 실시간 스트리밍은 방송자의 콘텐츠를 거의 동시에 시청자에게 전달합니다.
# 23. 하지만 전송 과정 때문에 약간의 지연 시간이 생길 수 있습니다.
# 24. 지연 시간은 라이브 방송과 시청 화면 사이의 시간 차이입니다.
# 25. 스트리밍은 스마트폰, 컴퓨터, 스마트TV 등 다양한 기기에서 이용할 수 있습니다.
# 26. 클라우드 게임도 게임 화면을 스트리밍하는 서비스의 한 종류입니다.
# 27. 스트리밍의 장점은 저장 공간을 많이 차지하지 않는다는 것입니다.
# 28. 또한 원하는 콘텐츠를 즉시 이용할 수 있다는 편리함이 있습니다.
# 29. 단점으로는 인터넷 연결이 불안정할 때 재생 품질이 떨어질 수 있습니다.
# 30. 즉, 스트리밍은 콘텐츠를 필요한 순간에 조금씩 받아 재생하는 방식입니다.

# %%
print(len(response_parts))
print(response_parts[0:10]) # chunk 단위이며, 604개로 총 이루어짐.
# Out:
# 604
# ['1', '.', ' 스트', '리', '밍', '은', ' 인터넷', '을', ' 통해', ' 콘텐츠']

# %% [markdown]
# ### 스트리밍 챗봇의 완성 응답 저장
#
# 반복 챗봇에서도 청크를 `response_parts`에 모아 이번 턴의 `assistant_message`를 만든다. 이렇게 갱신한 문자열을 `messages`에 추가하면, 다음 질문이 스트리밍으로 생성된 직전 답변까지 참조한다.

# %%
# 기본 지침 설정
messages = [{"role":"system", "content":"너는 젋은 꼰대 챗봇이야."}]

while True: # 무한루프
    user_input = input("사용자 입력 (종료는 exit)")

    if user_input.lower().strip() == 'exit':
        print("종료합니다")
        break

    # 사용자 입력 내용을 messages에 누적
    messages.append({"role":"user", "content":user_input})

    # stream 객체 생성
    stream = client.chat.completions.create(
        model = MODEL_NAME,
        messages = messages,
        stream=True,
    )

    # 입력 청크를 누적할 리스트
    response_parts = []
    print("Assistant:", end="")
    for chunk in stream:
        content = chunk.choices[0].delta.content
        if content:
            response_parts.append(content)
            print(content, end = "", flush=True)
    print()

    # Assistant의 응답을 다음 Messages에 누적
    assistant_message = "".join(response_parts)
    messages.append({"role":"assistant", "content":assistant_message})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 5
#       1 # 기본 지침 설정
#       2 messages = [{"role":"system", "content":"너는 젋은 꼰대 챗봇이야."}]
#       3
#       4 while True: # 무한루프
# ----> 5     user_input = input("사용자 입력 (종료는 exit)")
#       6
#       7     if user_input.lower().strip() == 'exit':
#       8         print("종료합니다")
#
# File ~\miniforge3\envs\llm_env\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\miniforge3\envs\llm_env\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## 토큰 수, usage와 비용 추정
#
# 토큰은 모델이 처리하는 텍스트 단위이며, 요청과 응답 토큰 수가 비용에 영향을 준다. 실제 청구에는 응답의 `usage`를 우선 사용하고, 요청 전 예상 비용은 토크나이저로 근사한다.
#
# 공식 문서: [텍스트 생성](https://developers.openai.com/api/docs/guides/text), [최신 모델 지침](https://developers.openai.com/api/docs/guides/latest-model)

# %% [markdown]
# ### tiktoken 설치
#
# `tiktoken`은 문자열을 토큰 ID로 변환해 요청 전 길이를 추정하는 라이브러리이다. 설치가 끝나면 다음 셀에서 `o200k_base` 인코딩으로 같은 문장의 토큰 수를 계산한다.

# %%
# !pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.13.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting regex (from tiktoken)
#   Using cached regex-2026.7.19-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from tiktoken) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests->tiktoken) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests->tiktoken) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests->tiktoken) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests->tiktoken) (2026.7.22)
# Downloading tiktoken-0.13.0-cp312-cp312-win_amd64.whl (874 kB)
#    ---------------------------------------- 0.0/874.7 kB ? eta -:--:--
#    ---------------------------------------- 874.7/874.7 kB 19.8 MB/s  0:00:00
# Using cached regex-2026.7.19-cp312-cp312-win_amd64.whl (277 kB)
# Installing collected packages: regex, tiktoken
#
#    ---------------------------------------- 0/2 [regex]
#    ---------------------------------------- 2/2 [tiktoken]
#
# Successfully installed regex-2026.7.19 tiktoken-0.13.0

# %% [markdown]
# ### 최신 예시 모델의 토크나이저 선택
#
# `o200k_base`는 GPT-5 계열 예시의 토큰 수를 근사하는 인코딩이다. 모델별 실제 토큰화와 API 사용량은 바뀔 수 있으므로, 청구나 정산에는 응답의 `usage`를 사용한다.

# %%
import tiktoken

gpt56_encoding = tiktoken.get_encoding("o200k_base")
print(gpt56_encoding)
# Out:
# <Encoding 'o200k_base'>

# %% [markdown]
# ### 짧은 문장의 토큰 수 계산
#
# 문장을 `encode()`에 넣으면 정수 토큰 ID 목록이 나온다. 목록 길이를 세어 입력 길이를 수치로 확인하고, 다음 긴 본문과 비용 계산의 기준으로 사용한다.

# %%
sample_text = "아버지가 방에 들어가신다."
encoded_sample = gpt56_encoding.encode(sample_text)

print(len(encoded_sample))
# Out:
# 10

# %% [markdown]
# ## 긴 입력의 토큰 수와 응답 usage
#
# 긴 기사 본문을 토큰화해 요청 전 입력 길이를 추정한다. 실제 API 호출 뒤에는 `response.usage`의 입력·출력 토큰 수를 읽어 추정값보다 신뢰도 높은 비용 근거로 사용한다.

# %% [markdown]
# ### 기사 본문의 입력 토큰 수 추정
#
# 긴 문자열 `text`를 준비하고 `gpt56_encoding`으로 토큰 ID 목록을 만든다. 출력된 길이는 다음 요약 요청의 예상 입력량과 비용 계산 함수의 입력이 된다.

# %%
text = """
정부가 인공지능(AI) 3대 강국으로 도약하기 위한 핵심 인프라 구축을 본격 시작했다. 정부는 전남광주 해남군에 AI 반도체 1만5000개를 갖춘 국가 AI 컴퓨팅센터를 기반으로 국내 AI 연구개발과 서비스 개발에 필요한 컴퓨팅 자원을 공급한다는 계획이다. 이와 함께 AI 인재 양성 프로젝트도 함께 가동해 ‘AI 풀스택 국가’ 구축에 속도를 낸다는 방침이다.

과학기술정보통신부는 3일 해남군 솔라시도 데이터센터 파크에서 국가 AI 컴퓨팅센터 착공식을 열었다고 밝혔다. 국가 AI 컴퓨팅센터는 정부가 추진하는 AI 고속도로의 핵심 인프라다.

삼성SDS 컨소시엄이 구축을 맡았으며 정부와 국민성장펀드, 민간이 공동 출자해 설립한 특수목적법인(SPC) ‘한국AI컴퓨팅센터(KOACC·코아크)’가 건설과 운영을 담당한다.
GPU 1.5만개 품는 AI 컴퓨팅센터, 해남서 첫삽이미지 크게보기
센터엔 2028년까지 그래픽처리장치(GPU) 1만5000개가 투입된다. 내년부터 삼성SDS 데이터센터에 일부 AI 자원을 먼저 개방해 산·학·연의 GPU 수요에 대응할 계획이다. 완공되면 연구개발(R&D)은 물론 국산 AI 반도체 검증과 상용화 테스트베드 역할도 맡는다. 정부는 R&D 전용 구역을 별도로 조성해 국내 AI 반도체 생태계 육성도 지원할 예정이다. 총 사업비는 약 2조5000억원이다.

배경훈 부총리 겸 과기정통부 장관은 이날 착공식에서 “국가 AI 컴퓨팅센터는 단순한 데이터센터가 아니라 토큰을 생산하는 AI 팩토리”라며 “대한민국이 메모리 반도체 공급국을 넘어 AI 공급망의 핵심 국가로 성장하는 기반이 될 것”이라고 강조했다. 그러면서 “정부도 AI 혁명의 골든타임을 놓치지 않도록 끝까지 지원하겠다”고 강조했다. 삼성SDS 출신인 안정태 코아크 대표는 “오늘의 착공이 대한민국을 AI 3대 강국으로 이끄는 출발점이 될 것”이라고 화답했다.

정부는 이날 국민 AI 활용 역량을 높이기 위한 ‘모두의 AI 성장 사다리 프로젝트’도 동시에 출범시켰다. 온라인 교육 플랫폼인 ‘모두의 AI 배움터’, AI 개발 플랫폼 ‘모두의 AI 실험실’, 지역 실증 공간인 ’모두의 AI 라운지’를 연결해 교육부터 개발, 창업까지 이어지는 체계를 구축한다는 구상이다.

특히 오프라인 거점인 모두의 AI 라운지에서는 시민이 개발한 AI 서비스를 직접 실증할 수 있다. 올해 수도권, 강원, 충청, 경상, 전라·제주 등 전국 5개 권역에 조성되며 AI 전문가가 개발을 지원한다.

배 부총리는 이날 국립광주과학관에서 열린 출범식에서 “AI는 이제 한글처럼 누구나 익히고 활용해야 하는 새로운 기본 역량”이라며 “배움터에서 배우고, 실험실에서 개발하고, 라운지에서 실증하는 선순환 구조를 마련해 AI 혜택을 모두가 누리는 AI 기본사회를 구축하겠다”고 말했다.
"""

encoded_text = gpt56_encoding.encode(text)
print("gpt-5.6-luna 예상 입력 토큰 수:", len(encoded_text))
# Out:
# gpt-5.6-luna 예상 입력 토큰 수: 800

# %% [markdown]
# ### 요약 응답의 usage 읽기
#
# 기사 `text`를 user 메시지로 보내고, `response.usage`에서 실제 입력·출력 토큰 수를 읽는다. 출력 텍스트는 비용 계산에, usage 값은 추정 토큰 수 검증에 사용한다.

# %%
response = client.chat.completions.create(
    model="gpt-5.6-luna",
    messages=[
        {"role": "system", "content": "제공된 뉴스 기사의 핵심을 간결하게 요약하는 챗봇이다."},
        {"role": "user", "content": text},
    ],
)

output_text = response.choices[0].message.content
usage = response.usage
print("요약 응답:", output_text)
print("입력 토큰:", usage.prompt_tokens)
print("출력 토큰:", usage.completion_tokens)
# Out:
# 요약 응답: 정부가 AI 3대 강국 도약을 위해 전남 해남에 국가 AI 컴퓨팅센터를 착공했다. 약 2조5000억 원을 투입해 2028년까지 GPU 1만5000개를 구축하고, AI 연구개발·국산 AI 반도체 검증·상용화 테스트를 지원할 계획이다.
#
# 이와 함께 온라인 교육, AI 개발 플랫폼, 지역 실증 공간을 연계한 ‘모두의 AI 성장 사다리 프로젝트’도 출범해 국민의 AI 활용 역량과 인재 양성을 강화한다.
# 입력 토큰: 831
# 출력 토큰: 131

# %% [markdown]
# ### 기준일이 있는 토큰 비용 계산
#
# 아래 값은 2026-08-03에 공식 모델 문서에서 확인한 표준 처리 단가이다.
#
# - `gpt-5.6-luna` 입력: 1M 토큰당 `$0.20`이다.
# - `gpt-5.6-luna` 캐시 입력: 1M 토큰당 `$0.02`이다.
# - `gpt-5.6-luna` 출력: 1M 토큰당 `$1.20`이다.
# - 입력이 272K 토큰을 넘으면 전체 요청에 입력 2배와 출력 1.5배 단가가 적용된다.
# - 캐시 쓰기는 캐시되지 않은 입력 단가의 1.25배이다.
#
# 가격과 처리 등급은 바뀔 수 있다. 운영 전에는 공식 페이지를 다시 확인한다.
#
# - [GPT-5.6 Luna 모델 문서](https://developers.openai.com/api/docs/models/gpt-5.6-luna)
# - [Pricing](https://developers.openai.com/api/docs/pricing)

# %%
PRICING = {
    "gpt-5.6-luna": {"input": 0.20, "output": 1.20},  # USD / 1M tokens
}

def calc_cost(input_tokens, output_tokens, model="gpt-5.6-luna"):
    price = PRICING[model]
    input_cost = input_tokens / 1_000_000 * price["input"]
    output_cost = output_tokens / 1_000_000 * price["output"]
    return input_cost + output_cost

request_cost = calc_cost(usage.prompt_tokens, usage.completion_tokens)
print(f"이번 요청의 추정 비용: ${request_cost:.8f}")
# Out:
# 이번 요청의 추정 비용: $0.00032340

# %% [markdown]
# ## 신규 프로젝트 권장 경로: Responses API
#
# Chat Completions는 계속 지원되지만, OpenAI는 신규 프로젝트에 Responses API를 권장한다. Responses API는 텍스트·이미지·도구 호출과 멀티턴 상태를 하나의 인터페이스에서 처리하므로 최신 추론 모델과 에이전트 기능을 연결하기 쉽다.
#
# - `input`에 사용자 요청을 전달한다.
# - `output_text`에서 최종 텍스트를 읽는다.
# - `previous_response_id`로 이전 응답을 이어 멀티턴 대화를 구성할 수 있다.
# - `reasoning.effort`로 작업에 사용할 추론 수준을 조정한다.
# - Chat Completions는 `messages`와 역할 기반 대화 구조를 학습하거나 기존 서비스를 유지할 때 사용한다.
#
# 공식 문서는 다음과 같다.
#
# - [Responses 생성 API](https://developers.openai.com/api/reference/resources/responses/methods/create)
# - [Chat Completions에서 Responses로 이전](https://developers.openai.com/api/docs/guides/migrate-to-responses)
# - [GPT-5.6 모델 지침](https://developers.openai.com/api/docs/guides/latest-model)
